# %% [markdown]
# <a href="https://colab.research.google.com/github/ManuelCarCas/Analitica-de-datos/blob/main/Extracci%C3%B3n_).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Instalar librerias
# !pip install pandas
# !pip install numpy
# !pip install matplotlib

# %%
#Importar archivos de datos 
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-87c6317c-9ac3-44e7-a0dd-b94df89de1fb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-87c6317c-9ac3-44e7-a0dd-b94df89de1fb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-304613de1931> in <module>()
#       1 #Importar archivos de datos
#       2 from google.colab import files
# ----> 3 uploaded = files.upload()
#
# /usr/local/lib/python3.7/dist-packages/google/colab/files.py in upload()
#      39   """
#      40
# ---> 41   uploaded_files = _upload_files(multiple=True)
#      42   # Mapping from original filename to filename as saved locally.
# ...

# %%
#Importamos la libreria pandas
import pandas as pd
import io

#Leemos el contenido del archivo 
#df = pd.read_csv(io.BytesIO(uploaded['file.csv']), index_col=2)
df = pd.read_csv('file.csv')
df.info()
df

#Importar archivo desde Github
#url = 'copied_raw_github_link'
#df = pd.read_csv(url)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4554 entries, 0 to 4553
# Data columns (total 7 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Periodo                                          4554 non-null   int64
#  1   Trimestre                                        4554 non-null   int64
#  2   Entidad_Federativa                               4554 non-null   object
#  3   Sexo                                             4554 non-null   object
#  4   Poblacion_ocupada_en_la_industria_manufacturera  4554 non-null   object
#  5   Poblaci n_ocupada                                4554 non-null   object
#  6   Tasa_de_ocupaci n_en_la_industria_manufacturera  4554 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 249.2+ KB
#       Periodo  Trimestre Entidad_Federativa     Sexo  \
# 0        2005          1           Nacional  Hombres
# ...

# %%
#Filtros básicos para variables cualitativas 
#Filtro por objeto
filtro1=df[df['Sexo'] == "Mujeres"]
filtro1
# Out:
#       Periodo  Trimestre   Entidad_Federativa     Sexo  \
# 1        2005          1             Nacional  Mujeres
# 3        2005          1       Aguascalientes  Mujeres
# 5        2005          1      Baja California  Mujeres
# 7        2005          1  Baja California Sur  Mujeres
# 9        2005          1             Campeche  Mujeres
# ...       ...        ...                  ...      ...
# 4545     2022          1           Tamaulipas  Mujeres
# 4547     2022          1             Tlaxcala  Mujeres
# 4549     2022          1             Veracruz  Mujeres
# 4551     2022          1              Yucat n  Mujeres
# 4553     2022          1            Zacatecas  Mujeres
#
#      Poblacion_ocupada_en_la_industria_manufacturera Poblaci n_ocupada  \
# 1                                            2690296          14843275
# 3                                              28430            145656
# 5                                             103697            398911
# ...

# %%
filtro2=df[df['Entidad_Federativa'] == "Puebla"]
filtro2
# Out:
#       Periodo  Trimestre Entidad_Federativa     Sexo  \
# 42       2005          1             Puebla  Hombres
# 43       2005          1             Puebla  Mujeres
# 108      2005          2             Puebla  Hombres
# 109      2005          2             Puebla  Mujeres
# 174      2005          3             Puebla  Hombres
# ...       ...        ...                ...      ...
# 4399     2021          3             Puebla  Mujeres
# 4464     2021          4             Puebla  Hombres
# 4465     2021          4             Puebla  Mujeres
# 4530     2022          1             Puebla  Hombres
# 4531     2022          1             Puebla  Mujeres
#
#      Poblacion_ocupada_en_la_industria_manufacturera Poblaci n_ocupada  \
# 42                                            230487           1341586
# 43                                            188720            817134
# 108                                           236459           1307234
# ...

# %%
#Filtro por filas
filtro3= df.iloc[50:550,: ] #Rango de filas 
#filtro3=df.iloc[ [1000, 2000, 3000] , :] #Filas específicas
filtro3
# Out:
#      Periodo  Trimestre Entidad_Federativa     Sexo  \
# 50      2005          1            Sinaloa  Hombres
# 51      2005          1            Sinaloa  Mujeres
# 52      2005          1             Sonora  Hombres
# 53      2005          1             Sonora  Mujeres
# 54      2005          1            Tabasco  Hombres
# ..       ...        ...                ...      ...
# 545     2007          1          Chihuahua  Mujeres
# 546     2007          1   Ciudad de M xico  Hombres
# 547     2007          1   Ciudad de M xico  Mujeres
# 548     2007          1            Durango  Hombres
# 549     2007          1            Durango  Mujeres
#
#     Poblacion_ocupada_en_la_industria_manufacturera Poblaci n_ocupada  \
# 50                                            77990            749476
# 51                                            53206            399694
# 52                                            91143            651067
# ...

# %%
#Filtro por columnas
#filtro4=df.iloc[ :, 2:5] #Rango de columnas 
filtro4=df.iloc[ : , [1,4,6]] #Columnas específicas
filtro4
# Out:
#       Trimestre Poblacion_ocupada_en_la_industria_manufacturera  \
# 0             1                                         4384907
# 1             1                                         2690296
# 2             1                                           56407
# 3             1                                           28430
# 4             1                                          167651
# ...         ...                                             ...
# 4549          1                                          107640
# 4550          1                                          101992
# 4551          1                                           82759
# 4552          1                                           44105
# 4553          1                                           39472
#
#      Tasa_de_ocupaci n_en_la_industria_manufacturera
# 0                           16.485975660000000000000
# 1                           18.124679360000000000000
# ...

# %%
#Filtro de filas vs columnas 
filtro5.loc[["Puebla", "Durango"]], ["Poblacion_ocupada_en_la_industria_manufacturera"]
filtro5 #Para aplicar este filtro se requiere una columna indice

# %%
#Filtro por cabecera
filtro6=df.head()
filtro6
# Out:
#    Periodo  Trimestre Entidad_Federativa     Sexo  \
# 0     2005          1           Nacional  Hombres
# 1     2005          1           Nacional  Mujeres
# 2     2005          1     Aguascalientes  Hombres
# 3     2005          1     Aguascalientes  Mujeres
# 4     2005          1    Baja California  Hombres
#
#   Poblacion_ocupada_en_la_industria_manufacturera Poblaci n_ocupada  \
# 0                                         4384907          26597801
# 1                                         2690296          14843275
# 2                                           56407            246177
# 3                                           28430            145656
# 4                                          167651            768989
#
#   Tasa_de_ocupaci n_en_la_industria_manufacturera
# 0                        16.485975660000000000000
# 1                        18.124679360000000000000
# 2                        22.913188480000000000000
# ...

# %%
#FILTROS BÁSCIOS PARA VARIABLES CUANTI
#Filtro por comparación
filtro7=df[df["Periodo"]>= 2006]
filtro7

# %%
#FILTROS BÁSCIOS CON CONETORES LOGICOS
#Filtro Y
filtro8=df[(df["Periodo"] > 2006) & (df["Sexo"] == "Mujeres")]
filtro8

# %%
#Filtro O
filtro9=df[(df["Periodo"] > 2020) | (df["Sexo"] == "Hombres")]
filtro9
# Out:
#       Periodo  Trimestre   Entidad_Federativa     Sexo  \
# 0        2005          1             Nacional  Hombres
# 2        2005          1       Aguascalientes  Hombres
# 4        2005          1      Baja California  Hombres
# 6        2005          1  Baja California Sur  Hombres
# 8        2005          1             Campeche  Hombres
# ...       ...        ...                  ...      ...
# 4549     2022          1             Veracruz  Mujeres
# 4550     2022          1              Yucat n  Hombres
# 4551     2022          1              Yucat n  Mujeres
# 4552     2022          1            Zacatecas  Hombres
# 4553     2022          1            Zacatecas  Mujeres
#
#      Poblacion_ocupada_en_la_industria_manufacturera Poblaci n_ocupada  \
# 0                                            4384907          26597801
# 2                                              56407            246177
# 4                                             167651            768989
# ...

# %%
#Filtro Not
filtro10= df[~(df["Periodo"] >= 2006) & (df["Sexo"] == "Mujeres")]
filtro10
# Out:
#      Periodo  Trimestre   Entidad_Federativa     Sexo  \
# 1       2005          1             Nacional  Mujeres
# 3       2005          1       Aguascalientes  Mujeres
# 5       2005          1      Baja California  Mujeres
# 7       2005          1  Baja California Sur  Mujeres
# 9       2005          1             Campeche  Mujeres
# ..       ...        ...                  ...      ...
# 255     2005          4           Tamaulipas  Mujeres
# 257     2005          4             Tlaxcala  Mujeres
# 259     2005          4             Veracruz  Mujeres
# 261     2005          4              Yucat n  Mujeres
# 263     2005          4            Zacatecas  Mujeres
#
#     Poblacion_ocupada_en_la_industria_manufacturera Poblaci n_ocupada  \
# 1                                           2690296          14843275
# 3                                             28430            145656
# 5                                            103697            398911
# ...

# %%
filtro10.to_csv("Entregable1.csv")

# %%
from google.colab import files
files.download("Entregable1.csv")
